# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cmap = plt.cm.tab20
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from collections import defaultdict
from src.woe_iv import WoeComputer, IvComputer
from src.preprocess import Binner
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
from src.train import WoeLogisticRegressionTrainer

# %% [markdown]
# ### Training the model

# %%
trainer = WoeLogisticRegressionTrainer("../dataset/germancredit.csv")

# %%
trainer.train_model()
# Out:
# all_accuracies [0.775   0.775   0.7625  0.80625 0.775  ]
# Average cv accuracy: 0.78%

# %%
trainer.show_performance()

# %%
# dir(trainer.model)

# %%
accuracy_score(trainer.train_ds.y, trainer.model.predict(trainer.train_ds.X))
# Out:
# 0.79

# %%
accuracy_score(trainer.test_ds.y, trainer.model.predict(trainer.test_ds.X))
# Out:
# 0.79
